# %% [markdown]
# <a href="https://colab.research.google.com/github/KasettyRohith/LETSUPGRADE_PYTHON/blob/master/Day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check():

  for item in listy:
    for i in lt:
      if i==item:
        check=1
        print(i,"its match")
        break      
  if check !=1:
    print(i,"its gonen")  
  else: 
    print(i,"its gone")

# %%
listy=[1,5,6,5,1,2,3,6]
lt=[1,1,5]
list(filter(check(),lt))
print()
# Out:
# 1 its match
# 5 its match
# 5 its match
# 1 its match
# 5 its gone

# %%
def checkprime(num):
  #n=int(input())
  checker=0
  for div in range(2,num//2+1):
    if num%2==0:
      checker=1
      print(num,"is not prime")
      break
  if num!=1 and checker==0:
    print(num,"is prime")

# %%
isrt=list(range(1,2501))
ist_prime=list(filter(checkprime,isrt))
# Out:
# 2 is prime
# 3 is prime
# 4 is not prime
# 5 is prime
# 6 is not prime
# 7 is prime
# 8 is not prime
# 9 is prime
# 10 is not prime
# 11 is prime
# 12 is not prime
# 13 is prime
# 14 is not prime
# 15 is prime
# 16 is not prime
# 17 is prime
# 18 is not prime
# 19 is prime
# 20 is not prime
# 21 is prime
# 22 is not prime
# 23 is prime
# 24 is not prime
# 25 is prime
# 26 is not prime
# 27 is prime
# 28 is not prime
# 29 is prime
# 30 is not prime
# 31 is prime
# 32 is not prime
# 33 is prime
# 34 is not prime
# 35 is prime
# 36 is not prime
# 37 is prime
# 38 is not prime
# 39 is prime
# 40 is not prime
# 41 is prime
# 42 is not prime
# 43 is prime
# 44 is not prime
# 45 is prime
# 46 is not prime
# 47 is prime
# 48 is not prime
# 49 is prime
# 50 is not prime
# 51 is prime
# 52 is not prime
# 53 is prime
# 54 is not prime
# 55 is prime
# 56 is not prime
# 57 is prime
# 58 is not prime
# 59 is prime
# 60 is not prime
# 61 is prime
# 62 is not prime
# 63 is prime
# 64 is not prime
# ...

# %%
lst=[input()]
lst_capl=map(lambda x: x.title(),lst)
print(list(lst_capl))
# Out:
# hi my name is rohith
# ['Hi My Name Is Rohith']

# %%
lrt=list(map(int,input().split()))
print(lrt)
sub_lst=list(map(int,input().split()))
check=0
for item in lrt:
  for i in sub_lst:
    if i==item:
      check=1
      print(i,"its match")
      break      
if check !=1:
  print(i,"its gonen")  
else: 
  print(i,"its gone")
# Out:
# 1 2 6 5
# [1, 2, 6, 5]
# 2 6 5
# 2 its match
# 6 its match
# 5 its match
# 5 its gone
